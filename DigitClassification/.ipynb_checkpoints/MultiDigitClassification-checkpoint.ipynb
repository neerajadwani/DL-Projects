# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
data_location='Multi_data/'
def load_data():
    X=np.load(data_location+'X.npy')
    y=np.load(data_location+'y.npy')
    return X,y

#print(os.getcwd())
X,y=load_data()
m, n = X.shape
print(X.shape,y.shape)
# Out:
# (5000, 400) (5000, 1)

# %% [markdown]
# Plotting Input data

# %%
fig,axes=plt.subplots(8,8,figsize=(8,8))
fig.tight_layout(pad=0.1)
for i,ax in enumerate(axes.flat):
    random_index = np.random.randint(m)
    # Select rows corresponding to the random indices and
    # reshape the image
    X_random_reshaped = X[random_index].reshape((20,20)).T
    # Display the image
    ax.imshow(X_random_reshaped, cmap='gray')
    # Display the label above the image
    ax.set_title(y[random_index,0])
    ax.set_axis_off()

# %%
model=Sequential([
    tf.keras.Input(shape=(400,)),
    Dense(units=25,activation='relu',name='layer1'),
    Dense(units=15,activation='relu',name='layer2'),
    Dense(units=10,activation='linear',name='layer3'),
],name='my_model')

model.compile(optimizer=Adam(learning_rate=0.01),loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
[layer1,layer2,layer3]=model.layers
W1,b1 = layer1.get_weights()
W2,b2 = layer2.get_weights()
W3,b3 = layer3.get_weights()
print(f"W1 shape = {W1.shape}, b1 shape = {b1.shape}")
print(f"W2 shape = {W2.shape}, b2 shape = {b2.shape}")
print(f"W3 shape = {W3.shape}, b3 shape = {b3.shape}")
# Out:
# W1 shape = (400, 25), b1 shape = (25,)
# W2 shape = (25, 15), b2 shape = (15,)
# W3 shape = (15, 10), b3 shape = (10,)

# %%
history=model.fit(X,y,epochs=40)
# Out:
# Epoch 1/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.6156 - accuracy: 0.8042
# Epoch 2/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.9122
# Epoch 3/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9326
# Epoch 4/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9450
# Epoch 5/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1607 - accuracy: 0.9498
# Epoch 6/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9540
# Epoch 7/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1184 - accuracy: 0.9598
# Epoch 8/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9686
# Epoch 9/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9672
# Epoch 10/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0886 - accuracy: 0.9736
# Epoch 11/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0968 - accuracy: 0.9664
# Epoch 12/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9696
# Epoch 13/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.9638
# Epoch 14/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9774
# Epoch 15/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9812: 0s - loss: 0.0507 - accu
# Epoch 16/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9780
# Epoch 17/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9752
# Epoch 18/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0539 - accuracy: 0.9822
# Epoch 19/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0472 - accuracy: 0.9850
# Epoch 20/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 0.9808
# Epoch 21/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0637 - accuracy: 0.9832
# Epoch 22/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0619 - accuracy: 0.9804
# Epoch 23/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0630 - accuracy: 0.9830
# Epoch 24/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0516 - accuracy: 0.9842
# Epoch 25/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0623 - accuracy: 0.9800
# Epoch 26/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0734 - accuracy: 0.9796
# Epoch 27/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0794 - accuracy: 0.9776
# Epoch 28/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 0.9902
# Epoch 29/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9854
# Epoch 30/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9802
# Epoch 31/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9840
# Epoch 32/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9840
# Epoch 33/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9840
# Epoch 34/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9864
# Epoch 35/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9836
# Epoch 36/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0373 - accuracy: 0.9884: 0s - loss: 0.0389
# Epoch 37/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0200 - accuracy: 0.9946
# Epoch 38/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9970
# Epoch 39/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9974
# Epoch 40/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9984

# %%
model.predict
